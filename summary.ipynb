# %% [markdown]
# # Strategy Results Summary
#
# One place to see all strategy results. Maximum drawdown and annualised return are stored as decimal rates.

# %%
# One place to see all results
results = {
    'SMA 20/50 AAPL': {'sharpe': 1.30, 'mdd': -0.1640, 'annual_return': 0.2002},
    'SMA 10/30 AAPL': {'sharpe': 1.19, 'mdd': -0.1214, 'annual_return': 0.2199},
    'Mean Rev INTC':  {'sharpe': 0.50, 'mdd': -0.4608, 'annual_return': 0.1071},
    'RSI INTC':       {'sharpe': 0.05, 'mdd': -0.4287, 'annual_return': 0.0680},
}

import pandas as pd
summary = pd.DataFrame(results).T
print(summary)
# Out:
#                 sharpe     mdd  annual_return
# SMA 20/50 AAPL    1.30 -0.1640         0.2002
# SMA 10/30 AAPL    1.19 -0.1214         0.2199
# Mean Rev INTC     0.50 -0.4608         0.1071
# RSI INTC          0.05 -0.4287         0.0680
